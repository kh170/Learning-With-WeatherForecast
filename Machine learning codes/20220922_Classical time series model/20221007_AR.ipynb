# %%
import pandas as pd
import numpy as np

from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")


# %run Functions.ipynb

# %%
dpath = r"/Users/bashirulazambiswas/Documents/Sadia/SUNY courses/2022_Fall/ICSI 518 Software Engineering/Project/Results/ML data/Station data"
path = r"/Users/bashirulazambiswas/Documents/Sadia/SUNY courses/2022_Fall/ICSI 518 Software Engineering/Project/Results/Classical time series models"
path = r"/Users/bashirulazambiswas/Documents/Sadia/SUNY courses/2022_Fall/ICSI 518 Software Engineering/Project/Results/Interpretations"

# %%
station_list = ['CHES']
target_list = ['temperature','humidity','precipitation']
window_list = [5,15,30]
train_method_list = ['prediction with target only','prediction with whole dataset']

# %%
# model = "AR"
# mae_df = pd.DataFrame(columns = ['station','model','train_method','target','window',"mae"])
# for station_name in station_list:
#     for train_method in train_method_list:
#         for target_variable in target_list:
#             for window in window_list:
#                 if train_method == 'prediction with target only':
#                     data = data_prep(dpath, station_name,target_variable)
#                     train,test =  TrainTestSplit(data,target_variable)
#                     mae = AR_model(path,train,test,target_variable,window,0,0,station_name,model,train_method)

#                     mae_df = mae_df.append({'station':station_name,'model':model,'train_method':train_method,
#                                             'target':target_variable,'window':window,'mae':mae},ignore_index = True)

# %%
# mae_df.to_csv(path+"/"+model+".csv")

# %%
model = ["AR","ARIMA","SARIMA","SVR","RF","LR",'RNN','LSTM']

for model_name in model:
    print(model_name)
    for station_name in station_list:
        for train_method in train_method_list:
            for target_variable in target_list:
                print(target_variable)
                for window in window_list:
                    print(window)
                    if model_name == 'AR' or model_name=='ARIMA' or model_name=='SARIMA':
                        if train_method == 'prediction with target only':
                            interpretation_text_classical(path,station_name,model_name,train_method,target_variable,window)
                    else:
                        interpretation_text_classical(path,station_name,model_name,train_method,target_variable,window)
# Out:
# AR
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# ARIMA
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# SARIMA
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# SVR
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# RF
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# LR
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# RNN
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# LSTM
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30
# temperature
# 5
# 15
# 30
# humidity
# 5
# 15
# 30
# precipitation
# 5
# 15
# 30

# %%
interpretation_text_classical(path,station_name,"LR",train_method,target_variable)
